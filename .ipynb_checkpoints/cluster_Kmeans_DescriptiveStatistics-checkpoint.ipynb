# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics.cluster import adjusted_rand_score

# %% [markdown]
# ## RGB DescriptiveStatistics

# %%
csv_data = pd.read_csv('data_csv/data_TPH_Ruifang_54stu.csv')
# csv_allX = csv_data[['total_avg', 'total_std', 'total_var', 'total_max', 'total_min', 'total_q25', 'total_q50', 'total_q75',
#                  'red_avg', 'red_std', 'red_var', 'red_max', 'red_min', 'red_q25', 'red_q50', 'red_q75',
#                  'green_avg', 'green_std', 'green_var', 'green_max', 'green_min', 'green_q25', 'green_q50', 'green_q75',
#                  'brown_avg', 'brown_std', 'brown_var', 'brown_max', 'brown_min', 'brown_q25', 'brown_q50', 'brown_q75']]
X = csv_data[['red_std', 'red_q25', 'red_q50', 'red_q75',
             'green_std', 'green_q25', 'green_q50', 'green_q75',
             'brown_std', 'brown_q25', 'brown_q50', 'brown_q75']]
y_true = csv_data["age"].values.tolist()

# %% [markdown]
# ### Kmeans & Silhouette

# %%
silhouette_avg = []
for i in range(2,20):
    kmeans_fit = KMeans(n_clusters=i, max_iter=1000).fit(X)
    silhouette_avg.append(silhouette_score(X, kmeans_fit.labels_))
plt.plot(range(2,20), silhouette_avg)

# %% [markdown]
# ### Kmeans & Adjusted Rand Index

# %%
k_means = KMeans(n_clusters=7, max_iter=1000)
k_means.fit(X) # 訓練
y_kmeans = k_means.predict(X) # 預測

# %%
adjusted_rand_score(y_true, y_kmeans)
# Out:
# -0.01963093835885355

# %% [markdown]
# ## R DescriptiveStatistics

# %%
csv_data = pd.read_csv('data_csv/data_TPH_Ruifang_54stu.csv')
X = csv_data[['red_std', 'red_q25', 'red_q50', 'red_q75']]
y_true = csv_data["age"].values.tolist()

# %%
silhouette_avg = []
for i in range(2,20):
    kmeans_fit = KMeans(n_clusters=i, max_iter=1000).fit(X)
    silhouette_avg.append(silhouette_score(X, kmeans_fit.labels_))
plt.plot(range(2,20), silhouette_avg)

# %%
k_means = KMeans(n_clusters=8, max_iter=1000)
k_means.fit(X) # 訓練
y_kmeans = k_means.predict(X) # 預測

# %%
adjusted_rand_score(y_true, y_kmeans)
# Out:
# -0.010405297242232409

# %% [markdown]
# ## G DescriptiveStatistics

# %%
csv_data = pd.read_csv('data_csv/data_TPH_Ruifang_54stu.csv')
X = csv_data[['green_std', 'green_q25', 'green_q50', 'green_q75']]
y_true = csv_data["age"].values.tolist()

# %%
silhouette_avg = []
for i in range(2,20):
    kmeans_fit = KMeans(n_clusters=i, max_iter=1000).fit(X)
    silhouette_avg.append(silhouette_score(X, kmeans_fit.labels_))
plt.plot(range(2,20), silhouette_avg)

# %%
k_means = KMeans(n_clusters=6, max_iter=1000)
k_means.fit(X) # 訓練
y_kmeans = k_means.predict(X) # 預測

# %%
adjusted_rand_score(y_true, y_kmeans)
# Out:
# 0.00913134175620892

# %% [markdown]
# ## B DescriptiveStatistics

# %%
csv_data = pd.read_csv('data_csv/data_TPH_Ruifang_54stu.csv')
X = csv_data[['brown_std', 'brown_q25', 'brown_q50', 'brown_q75']]
y_true = csv_data["age"].values.tolist()

# %%
silhouette_avg = []
for i in range(2,20):
    kmeans_fit = KMeans(n_clusters=i, max_iter=1000).fit(X)
    silhouette_avg.append(silhouette_score(X, kmeans_fit.labels_))
plt.plot(range(2,20), silhouette_avg)

# %%
k_means = KMeans(n_clusters=3, max_iter=1000)
k_means.fit(X) # 訓練
y_kmeans = k_means.predict(X) # 預測

# %%
adjusted_rand_score(y_true, y_kmeans)
# Out:
# -0.020224171539961013
